# %%
import pandas as pd
import os
from getpass import getpass

# %%
df = pd.read_csv("/content/2004-2021.tsv", sep='\t', index_col=0)

# %%
df.head()
# Out:
#               DATA FINAL        REGIÃO              ESTADO           PRODUTO  \
# DATA INICIAL
# 2004-05-09    2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 2004-05-09    2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2004-05-09    2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 2004-05-09    2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 2004-05-09    2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# DATA INICIAL
# 2004-05-09                             127              R$/l
# 2004-05-09                             387              R$/l
# 2004-05-09                             192              R$/l
# 2004-05-09                             162              R$/l
# 2004-05-09                             103              R$/l
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# DATA INICIAL
# 2004-05-09                  1.288                  0.016
# 2004-05-09                  1.162                  0.114
# 2004-05-09                  1.389                  0.097
# 2004-05-09                  1.262                  0.070
# 2004-05-09                  1.181                  0.078
#
#               PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  \
# DATA INICIAL
# 2004-05-09                    1.19                 1.350                0.463
# 2004-05-09                    0.89                 1.449                0.399
# 2004-05-09                    1.18                 1.760                0.419
# 2004-05-09                    1.09                 1.509                0.432
# 2004-05-09                    1.05                 1.400                 0.24
#
#               COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# DATA INICIAL
# 2004-05-09                       0.012                    0.825
# 2004-05-09                       0.098                    0.763
# 2004-05-09                       0.070                     0.97
# 2004-05-09                       0.055                     0.83
# 2004-05-09                       0.066                    0.941
#
#              DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# DATA INICIAL
# 2004-05-09                         0.11                    0.4201
# 2004-05-09                        0.088                    0.5013
# 2004-05-09                        0.095                    0.5614
# 2004-05-09                        0.119                    0.5991
# 2004-05-09                        0.077                    0.7441
#
#              PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# DATA INICIAL
# 2004-05-09                      0.9666                         0.133
# 2004-05-09                        1.05                         0.115
# 2004-05-09                       1.161                         0.098
# 2004-05-09                     1.22242                         0.143
# 2004-05-09                      1.0317                         0.082

# %%
username = "italofvaz" # insira o seu nome de usuário do git
os.environ["GITHUB_USER"] = username

# !git config --global user.name "${GITHUB_USER}"

# %%
usermail = getpass()
os.environ["GITHUB_MAIL"] = usermail

# !git config --global user.email "${GITHUB_MAIL}"
# Out:
# ··········

# %%
usertoken = getpass()
os.environ["GITHUB_TOKEN"] = usertoken

# !git clone https://${GITHUB_USER}:${GITHUB_TOKEN}@github.com/italofvaz/gas_price_brazil.git
# Out:
# ··········
# Cloning into 'gas_price_brazil'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd /content/gas_price_brazil/
# Out:
# /content/gas_price_brazil

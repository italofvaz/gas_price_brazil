# %%
import pandas as pd
import os
from getpass import getpass

# %%
df = pd.read_csv("/content/gas_price_brazil/2004-2021.tsv", sep='\t')

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                         0.133
# 1                         0.115
# 2                         0.098
# 3                         0.143
# 4                         0.082

# %% [markdown]
# Initial Inspection and Data Quality

# %%
print(df.shape)  # number of line and columns
# Out:
# (120823, 18)

# %%
df.info() # Verifying data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  object
#  1   DATA FINAL                     120823 non-null  object
#  2   REGIÃO                         120823 non-null  object
#  3   ESTADO                         120823 non-null  object
#  4   PRODUTO                        120823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  object
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       120823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       120823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     120823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      120823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      120823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  120823 non-null  object
# dtypes: float64(5), int64(1), object(12)
# memory usage: 16.6+ MB

# %%
df.isnull().sum() # null values
# Out:
# DATA INICIAL                     0
# DATA FINAL                       0
# REGIÃO                           0
# ESTADO                           0
# PRODUTO                          0
# NÚMERO DE POSTOS PESQUISADOS     0
# UNIDADE DE MEDIDA                0
# PREÇO MÉDIO REVENDA              0
# DESVIO PADRÃO REVENDA            0
# PREÇO MÍNIMO REVENDA             0
# PREÇO MÁXIMO REVENDA             0
# MARGEM MÉDIA REVENDA             0
# COEF DE VARIAÇÃO REVENDA         0
# PREÇO MÉDIO DISTRIBUIÇÃO         0
# DESVIO PADRÃO DISTRIBUIÇÃO       0
# PREÇO MÍNIMO DISTRIBUIÇÃO        0
# PREÇO MÁXIMO DISTRIBUIÇÃO        0
# COEF DE VARIAÇÃO DISTRIBUIÇÃO    0
# dtype: int64

# %%
df.duplicated().sum()  # Detect and remove duplicate records.
# Out:
# np.int64(0)

# %% [markdown]
# Descriptive Statistical Analysis

# %%
df.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 120823.000000        120823.000000
# mean                     221.066461            11.473440
# std                      387.940239            19.161823
# min                        1.000000             0.766000
# 25%                       39.000000             2.157000
# 50%                       99.000000             2.899000
# 75%                      226.000000             4.026000
# max                     4167.000000           107.500000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          120823.000000         120823.000000         120823.000000
# mean                0.684132              9.977821             13.233902
# std                 1.403317             16.433783             22.451445
# min                 0.000000              0.590000              0.999000
# 25%                 0.075000              1.989000              2.420000
# 50%                 0.121000              2.690000              3.200000
# 75%                 0.204000              3.790000              4.589000
# max                10.748000            100.000000            120.000000
#
#        COEF DE VARIAÇÃO REVENDA
# count             120823.000000
# mean                   0.045298
# std                    0.024763
# min                    0.000000
# 25%                    0.029000
# 50%                    0.041000
# 75%                    0.058000
# max                    0.395000

# %% [markdown]
# ##EDA

# %%
df['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 120818    2021-04-25
# 120819    2021-04-25
# 120820    2021-04-25
# 120821    2021-04-25
# 120822    2021-04-25
# Name: DATA INICIAL, Length: 120823, dtype: object

# %%
df['DATA INICIAL'] = pd.to_datetime(df['DATA INICIAL'])
df['DATA FINAL'] = pd.to_datetime(df['DATA FINAL'])

# %%
df['ANO MES'] = df['DATA FINAL'].apply(lambda x : '{}'.format(x.year)) + df['DATA FINAL'].apply(lambda x : '-{:02d}'.format(x.month))

# %%
df['ANO MES']
# Out:
# 0         2004-05
# 1         2004-05
# 2         2004-05
# 3         2004-05
# 4         2004-05
#            ...
# 120818    2021-05
# 120819    2021-05
# 120820    2021-05
# 120821    2021-05
# 120822    2021-05
# Name: ANO MES, Length: 120823, dtype: object

# %%
df.columns
# Out:
# Index(['DATA INICIAL', 'DATA FINAL', 'REGIÃO', 'ESTADO', 'PRODUTO',
#        'NÚMERO DE POSTOS PESQUISADOS', 'UNIDADE DE MEDIDA',
#        'PREÇO MÉDIO REVENDA', 'DESVIO PADRÃO REVENDA', 'PREÇO MÍNIMO REVENDA',
#        'PREÇO MÁXIMO REVENDA', 'MARGEM MÉDIA REVENDA',
#        'COEF DE VARIAÇÃO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO',
#        'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO',
#        'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO',
#        'ANO MES'],
#       dtype='object')

# %% [markdown]
# # filtering the dataframe only with the GASOLINA COMUM registers

# %%
df['PRODUTO'].value_counts()
# Out:
# PRODUTO
# GASOLINA COMUM        23570
# GLP                   23561
# ETANOL HIDRATADO      23440
# ÓLEO DIESEL           21194
# GNV                   14469
# ÓLEO DIESEL S10        9113
# OLEO DIESEL S10        2376
# OLEO DIESEL            2351
# GASOLINA ADITIVADA      749
# Name: count, dtype: int64

# %%
df2 = df[df['PRODUTO'] == "GASOLINA COMUM"]

# %%
df2
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO              ESTADO  \
# 12064    2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 12065    2004-05-09 2004-05-15  CENTRO OESTE               GOIAS
# 12066    2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO
# 12067    2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 12068    2004-05-09 2004-05-15      NORDESTE             ALAGOAS
# ...             ...        ...           ...                 ...
# 120721   2021-04-25 2021-05-01         NORTE             RORAIMA
# 120722   2021-04-25 2021-05-01           SUL      SANTA CATARINA
# 120723   2021-04-25 2021-05-01       SUDESTE           SAO PAULO
# 120724   2021-04-25 2021-05-01      NORDESTE             SERGIPE
# 120725   2021-04-25 2021-05-01         NORTE           TOCANTINS
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 12064   GASOLINA COMUM                           128              R$/l
# 12065   GASOLINA COMUM                           395              R$/l
# 12066   GASOLINA COMUM                           194              R$/l
# 12067   GASOLINA COMUM                           166              R$/l
# 12068   GASOLINA COMUM                           106              R$/l
# ...                ...                           ...               ...
# 120721  GASOLINA COMUM                            12              R$/l
# 120722  GASOLINA COMUM                           119              R$/l
# 120723  GASOLINA COMUM                          1187              R$/l
# 120724  GASOLINA COMUM                            34              R$/l
# 120725  GASOLINA COMUM                            20              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 12064                 2.029                  0.007                 1.990
# 12065                 2.025                  0.062                 1.850
# 12066                 2.358                  0.066                 2.000
# 12067                 2.120                  0.075                 1.970
# 12068                 2.090                  0.034                 2.000
# ...                     ...                    ...                   ...
# 120721                5.364                  0.065                 5.310
# 120722                5.051                  0.251                 4.640
# 120723                5.265                  0.218                 4.279
# 120724                5.586                  0.088                 5.410
# 120725                5.751                  0.160                 5.578
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 12064                  2.070                0.318                     0.003
# 12065                  2.220                0.296                     0.031
# 12066                  2.540                0.472                     0.028
# 12067                  2.440                0.325                     0.035
# 12068                  2.159                 0.35                     0.016
# ...                      ...                  ...                       ...
# 120721                 5.530             -99999.0                     0.012
# 120722                 5.599             -99999.0                     0.050
# 120723                 6.099             -99999.0                     0.041
# 120724                 5.699             -99999.0                     0.016
# 120725                 6.119             -99999.0                     0.028
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12064                     1.711                       0.02
# 12065                     1.729                      0.036
# 12066                     1.886                      0.068
# 12067                     1.795                      0.033
# 12068                      1.74                      0.042
# ...                         ...                        ...
# 120721                 -99999.0                   -99999.0
# 120722                 -99999.0                   -99999.0
# 120723                 -99999.0                   -99999.0
# 120724                 -99999.0                   -99999.0
# 120725                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12064                      1.651                    1.7427
# 12065                     1.6643                     1.915
# 12066                       1.75                    2.0713
# 12067                    1.70701                    1.9703
# 12068                     1.6789                     1.918
# ...                          ...                       ...
# 120721                  -99999.0                  -99999.0
# 120722                  -99999.0                  -99999.0
# 120723                  -99999.0                  -99999.0
# 120724                  -99999.0                  -99999.0
# 120725                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  ANO MES
# 12064                          0.012  2004-05
# 12065                          0.021  2004-05
# 12066                          0.036  2004-05
# 12067                          0.018  2004-05
# 12068                          0.024  2004-05
# ...                              ...      ...
# 120721                      -99999.0  2021-05
# 120722                      -99999.0  2021-05
# 120723                      -99999.0  2021-05
# 120724                      -99999.0  2021-05
# 120725                      -99999.0  2021-05
#
# [23570 rows x 19 columns]

# %% [markdown]
# # Average gasoline price in August 2008

# %%
df2[df['ANO MES'] == '2008-09']['PREÇO MÉDIO REVENDA'].mean()
# Out:
# <ipython-input-23-7d5cb09bd601>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2[df['ANO MES'] == '2008-09']['PREÇO MÉDIO REVENDA'].mean()
# np.float64(2.611009259259259)

# %% [markdown]
# # Average gasoline price in August 2008 in Sao Paulo

# %% [markdown]
# estrutura de colchetes
#
# > [selection] [[list of columns or only one list]]

# %%
df2[(df2['ANO MES'] == '2008-09') & (df2['ESTADO'] == 'SAO PAULO')]['PREÇO MÉDIO REVENDA'].mean()
# Out:
# np.float64(2.40325)

# %% [markdown]
# #When did the gas price go up to 5 dollars, and in which state did that happen?

# %%
df2[df2['PREÇO MÁXIMO REVENDA'] > 5][['ANO MES', 'ESTADO', 'PREÇO MÉDIO REVENDA']]
# Out:
#         ANO MES          ESTADO  PREÇO MÉDIO REVENDA
# 92471   2017-09            ACRE                4.373
# 92771   2017-09            ACRE                4.496
# 93072   2017-09            ACRE                4.516
# 93371   2017-10            ACRE                4.521
# 93671   2017-10            ACRE                4.524
# ...         ...             ...                  ...
# 120721  2021-05         RORAIMA                5.364
# 120722  2021-05  SANTA CATARINA                5.051
# 120723  2021-05       SAO PAULO                5.265
# 120724  2021-05         SERGIPE                5.586
# 120725  2021-05       TOCANTINS                5.751
#
# [1599 rows x 3 columns]

# %% [markdown]
# #Average gas price at the south states in 2012

# %%
df_south = df2[(df2['REGIÃO'] == 'SUL')]

# %%
df_south[df_south['DATA INICIAL'].apply(lambda x: x.year) == 2012]['PREÇO MÁXIMO REVENDA'].mean()
# Out:
# np.float64(3.0785723270440246)

# %% [markdown]
# ##Year-over-year percentage change in gasoline prices in the state of Rio de Janeiro

# %%
df_rio = df2[df2['ESTADO'] == 'RIO DE JANEIRO']

# %%
df_rio['ANO'] = df_rio['DATA INICIAL'].apply(lambda x: '{}'.format(x.year))
# Out:
# <ipython-input-29-f9ebd2d929bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rio['ANO'] = df_rio['DATA INICIAL'].apply(lambda x: '{}'.format(x.year))

# %%
df_rio.groupby('ANO')['PREÇO MÉDIO REVENDA'].mean()
# Out:
# ANO
# 2004    2.175500
# 2005    2.339500
# 2006    2.560679
# 2007    2.532288
# 2008    2.547308
# 2009    2.566120
# 2010    2.648673
# 2011    2.835846
# 2012    2.853698
# 2013    2.998885
# 2014    3.134635
# 2015    3.549882
# 2016    3.919192
# 2017    4.112774
# 2018    4.858058
# 2019    4.858173
# 2020    4.761205
# 2021    5.625294
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
(df_rio_perct / df_rio_perct.shift(1) -1)*100

# %%
dfrio

# %% [markdown]
# ### Time series with absolute and percentage differences between the lowest and highest prices, separated by state.

# %%
df_max = df2.groupby('ANO MES').max()['PREÇO MÉDIO REVENDA']

# %%
df_min = df2.groupby('ANO MES').min()['PREÇO MÉDIO REVENDA']

# %%
df_max
# Out:
# ANO MES
# 2004-05    2.438
# 2004-06    2.496
# 2004-07    2.545
# 2004-08    2.560
# 2004-09    2.570
#            ...
# 2021-01    5.213
# 2021-02    5.809
# 2021-03    6.688
# 2021-04    6.227
# 2021-05    6.258
# Name: PREÇO MÉDIO REVENDA, Length: 204, dtype: float64

# %%
df_diff = pd.DataFrame()

# %%
df_diff['abs_diff'] = df_max - df_min

# %%
df_diff['perct'] = (df_max - df_min) / df_min * 100

# %%
df_diff
# Out:
#          abs_diff      perct    max    min
# ANO MES
# 2004-05     0.550  29.131356  2.438  1.888
# 2004-06     0.584  30.543933  2.496  1.912
# 2004-07     0.609  31.456612  2.545  1.936
# 2004-08     0.530  26.108374  2.560  2.030
# 2004-09     0.539  26.538651  2.570  2.031
# ...           ...        ...    ...    ...
# 2021-01     1.383  36.109661  5.213  3.830
# 2021-02     1.688  40.960932  5.809  4.121
# 2021-03     2.109  46.058091  6.688  4.579
# 2021-04     1.450  30.353779  6.227  4.777
# 2021-05     1.391  28.580234  6.258  4.867
#
# [204 rows x 4 columns]

# %%
df2.groupby('ANO MES').idxmax()
# Out:
#          DATA INICIAL  DATA FINAL  REGIÃO  ESTADO  PRODUTO  \
# ANO MES
# 2004-05         12118       12118   12088   12083    12064
# 2004-06         12226       12226   12169   12164    12145
# 2004-07         12361       12361   12277   12272    12253
# 2004-08         12469       12469   12412   12407    12388
# 2004-09         12577       12577   12520   12515    12496
# ...               ...         ...     ...     ...      ...
# 2021-01        118384      118384  117698  117709   117683
# 2021-02        119092      119092  118575  118586   118560
# 2021-03        119807      119807  119284  119295   119269
# 2021-04        120520      120520  120000  120011   119985
# 2021-05        120699      120699  120714  120725   120699
#
#          NÚMERO DE POSTOS PESQUISADOS  UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ANO MES
# 2004-05                         12141              12064                12104
# 2004-06                         12249              12145                12228
# 2004-07                         12330              12253                12374
# 2004-08                         12438              12388                12471
# 2004-09                         12600              12496                12590
# ...                               ...                ...                  ...
# 2021-01                        118408             117683               118208
# 2021-02                        119116             118560               119092
# 2021-03                        119293             119269               119629
# 2021-04                        120544             119985               120163
# 2021-05                        120723             120699               120699
#
#          DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ANO MES
# 2004-05                  12077                 12104                 12077
# 2004-06                  12158                 12185                 12243
# 2004-07                  12367                 12347                 12347
# 2004-08                  12428                 12471                 12401
# 2004-09                  12536                 12563                 12509
# ...                        ...                   ...                   ...
# 2021-01                 118208                118384                118208
# 2021-02                 118750                119092                119092
# 2021-03                 119810                119629                119449
# 2021-04                 120362                119985                120183
# 2021-05                 120703                120699                120699
#
#          MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# ANO MES
# 2004-05                 12131                     12098
# 2004-06                 12185                     12158
# 2004-07                 12347                     12367
# 2004-08                 12428                     12395
# 2004-09                 12590                     12536
# ...                       ...                       ...
# 2021-01                117683                    118208
# 2021-02                118560                    118750
# 2021-03                119269                    119810
# 2021-04                119985                    119988
# 2021-05                120699                    120703
#
#          PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# ANO MES
# 2004-05                     12107                       12120
# 2004-06                     12242                       12249
# 2004-07                     12363                       12266
# 2004-08                     12483                       12404
# 2004-09                     12552                       12525
# ...                           ...                         ...
# 2021-01                    117683                      117683
# 2021-02                    118560                      118560
# 2021-03                    119269                      119269
# 2021-04                    119985                      119985
# 2021-05                    120699                      120699
#
#          PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# ANO MES
# 2004-05                      12078                      12140
# 2004-06                      12213                      12249
# 2004-07                      12348                      12303
# 2004-08                      12483                      12439
# 2004-09                      12591                      12545
# ...                            ...                        ...
# 2021-01                     117683                     117683
# 2021-02                     118560                     118560
# 2021-03                     119269                     119269
# 2021-04                     119985                     119985
# 2021-05                     120699                     120699
#
#          COEF DE VARIAÇÃO DISTRIBUIÇÃO
# ANO MES
# 2004-05                          12087
# 2004-06                          12249
# 2004-07                          12266
# 2004-08                          12438
# 2004-09                          12519
# ...                                ...
# 2021-01                         117683
# 2021-02                         118560
# 2021-03                         119269
# 2021-04                         119985
# 2021-05                         120699
#
# [204 rows x 18 columns]

# %%
idx_max = df2.groupby('ANO MES')['PREÇO MÉDIO REVENDA'].idxmax()

# %%
idx_min = df2.groupby('ANO MES')['PREÇO MÉDIO REVENDA'].idxmin()

# %%
df_diff['max'] = df_max
df_diff['min'] = df_min

# %%
df2.loc[idx_max, :][['ESTADO', 'PREÇO MÉDIO REVENDA', 'ANO MES']]
# Out:
#              ESTADO  PREÇO MÉDIO REVENDA  ANO MES
# 12104          ACRE                2.438  2004-05
# 12228   MATO GROSSO                2.496  2004-06
# 12374          ACRE                2.545  2004-07
# 12471   MATO GROSSO                2.560  2004-08
# 12590          ACRE                2.570  2004-09
# ...             ...                  ...      ...
# 118208         ACRE                5.213  2021-01
# 119092         ACRE                5.809  2021-02
# 119629         ACRE                6.688  2021-03
# 120163         ACRE                6.227  2021-04
# 120699         ACRE                6.258  2021-05
#
# [204 rows x 3 columns]

# %%
df_diff['ESTADO MAX'] = df2.loc[idx_max, :]['ESTADO'].values

# %%
df_diff['ESTADO MIN'] = df2.loc[idx_min, :]['ESTADO'].values

# %%
df_diff
# Out:
#          abs_diff      perct    max    min   ESTADO MAX        ESTADO MIN
# ANO MES
# 2004-05     0.550  29.131356  2.438  1.888         ACRE         SAO PAULO
# 2004-06     0.584  30.543933  2.496  1.912  MATO GROSSO         SAO PAULO
# 2004-07     0.609  31.456612  2.545  1.936         ACRE  DISTRITO FEDERAL
# 2004-08     0.530  26.108374  2.560  2.030  MATO GROSSO         SAO PAULO
# 2004-09     0.539  26.538651  2.570  2.031         ACRE         SAO PAULO
# ...           ...        ...    ...    ...          ...               ...
# 2021-01     1.383  36.109661  5.213  3.830         ACRE             AMAPA
# 2021-02     1.688  40.960932  5.809  4.121         ACRE             AMAPA
# 2021-03     2.109  46.058091  6.688  4.579         ACRE             AMAPA
# 2021-04     1.450  30.353779  6.227  4.777         ACRE             AMAPA
# 2021-05     1.391  28.580234  6.258  4.867         ACRE             AMAPA
#
# [204 rows x 6 columns]

# %%
df_diff['ESTADO MAX'].value_counts()
# Out:
# ESTADO MAX
# ACRE              166
# MATO GROSSO        25
# RIO DE JANEIRO     11
# RORAIMA             2
# Name: count, dtype: int64

# %%
df_diff['ESTADO MIN'].value_counts()
# Out:
# ESTADO MIN
# SAO PAULO              40
# AMAPA                  38
# PIAUI                  28
# PARAIBA                28
# PARANA                 14
# AMAZONAS               14
# DISTRITO FEDERAL       12
# MARANHAO                9
# SANTA CATARINA          6
# PERNAMBUCO              4
# MATO GROSSO DO SUL      3
# RIO GRANDE DO NORTE     2
# GOIAS                   2
# BAHIA                   2
# CEARA                   2
# Name: count, dtype: int64

# %%
username = "italofvaz"
os.environ["GITHUB_USER"] = username

# !git config --global user.name "${GITHUB_USER}"

# %%
usermail = getpass()
os.environ["GITHUB_MAIL"] = usermail

# !git config --global user.email "${GITHUB_MAIL}"
# Out:
# ··········

# %%
usertoken = getpass()
os.environ["GITHUB_TOKEN"] = usertoken

# !git clone https://${GITHUB_USER}:${GITHUB_TOKEN}@github.com/italofvaz/gas_price_brazil.git
# Out:
# ··········
# Cloning into 'gas_price_brazil'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 32 (delta 13), reused 20 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 6.19 MiB | 14.95 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# %cd /content/gas_price_brazil/
# Out:
# /content/gas_price_brazil

# %%
# !git add .

# !git commit -m "test"

# !git push origin main
# Out:
# [main 8ed6367] test
#  1 file changed, 3366 insertions(+)
#  create mode 100644 eda_gas_price_brazil_test.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 15.50 KiB | 5.17 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/italofvaz/gas_price_brazil.git
#    eb801f1..8ed6367  main -> main
